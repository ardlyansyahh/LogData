# %% [markdown]
# # Data Acquisition & Preparation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_employee = pd.read_csv('dataset/employee_survey_data.csv')
df_employee.head()
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
df_general = pd.read_csv('dataset/general_data.csv')
df_general.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df_in_time = pd.read_csv('dataset/in_time.csv')
df_in_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06  ...
# ...

# %%
df_manager = pd.read_csv('dataset/manager_survey_data.csv')
df_manager.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
df_out_time = pd.read_csv('dataset/out_time.csv')
df_out_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  ...  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58  ...
# ...

# %%
df_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# ### Missing Values

# %%
print("Employee")
df_employee.isna().sum()
# Out:
# Employee
# EmployeeID                  0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
df_employee.fillna({'EnvironmentSatisfaction':df_employee['EnvironmentSatisfaction'].mode()[0]}, inplace=True)
df_employee.fillna({'JobSatisfaction':df_employee['JobSatisfaction'].mode()[0]}, inplace=True)
df_employee.fillna({'WorkLifeBalance':df_employee['WorkLifeBalance'].mode()[0]}, inplace=True)
df_employee.isna().sum()
# Out:
# EmployeeID                 0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# dtype: int64

# %%
print("Manager")
df_manager.isna().sum()
# Out:
# Manager
# EmployeeID           0
# JobInvolvement       0
# PerformanceRating    0
# dtype: int64

# %%
print("general")
df_general.isna().sum()
# Out:
# general
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
sns.kdeplot(df_general['NumCompaniesWorked'])
# Out:
# <Axes: xlabel='NumCompaniesWorked', ylabel='Density'>

# %%
sns.kdeplot(df_general['TotalWorkingYears'])
# Out:
# <Axes: xlabel='TotalWorkingYears', ylabel='Density'>

# %%
df_general.fillna({'NumCompaniesWorked':df_general['NumCompaniesWorked'].mode()[0]}, inplace=True)
df_general.fillna({'TotalWorkingYears':df_general['TotalWorkingYears'].mode()[0]}, inplace=True)
df_general.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df_in_time.isna().sum()
# Out:
# Unnamed: 0       0
# 2015-01-01    4410
# 2015-01-02     209
# 2015-01-05     206
# 2015-01-06     228
#               ...
# 2015-12-25    4410
# 2015-12-28     234
# 2015-12-29     230
# 2015-12-30     265
# 2015-12-31     213
# Length: 262, dtype: int64

# %%
df_out_time.isna().sum()
# Out:
# Unnamed: 0       0
# 2015-01-01    4410
# 2015-01-02     209
# 2015-01-05     206
# 2015-01-06     228
#               ...
# 2015-12-25    4410
# 2015-12-28     234
# 2015-12-29     230
# 2015-12-30     265
# 2015-12-31     213
# Length: 262, dtype: int64

# %%
if ((df_in_time.isna().sum()).equals(df_out_time.isna().sum())):
    print("Jumlah Nilai Null Sama")
else:
    comparation = (df_in_time.isna().sum()).compare(df_out_time.isna().sum())
    print(comparation)
# Out:
# Jumlah Nilai Null Sama

# %% [markdown]
# ### Duplikasi

# %%
print("Employee")
df_employee.duplicated().sum()
# Out:
# Employee
# np.int64(0)

# %%
print("Manager")
df_manager.duplicated().sum()
# Out:
# Manager
# np.int64(0)

# %%
print("general")
df_general.duplicated().sum()
# Out:
# general
# np.int64(0)

# %%
print("in time")
df_in_time.duplicated().sum()
# Out:
# in time
# np.int64(0)

# %%
print("out time")
df_out_time.duplicated().sum()
# Out:
# out time
# np.int64(0)

# %% [markdown]
# ### Outliers

# %%
df_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4410 non-null   float64
#  2   JobSatisfaction          4410 non-null   float64
#  3   WorkLifeBalance          4410 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 137.9 KB

# %%
features = df_employee.columns
for i in range(0, len(features)):
    plt.subplot(2, 2, i+1)
    sns.boxplot(df_employee[features[i]])

# %%
df_manager.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         4410 non-null   int64
#  1   JobInvolvement     4410 non-null   int64
#  2   PerformanceRating  4410 non-null   int64
# dtypes: int64(3)
# memory usage: 103.5 KB

# %%
features = df_manager.columns
for i in range(0, len(features)):
    plt.subplot(2, 2, i+1)
    sns.boxplot(df_manager[features[i]])

# %%
for i in range(0, len(features)):
    plt.subplot(2, 3, i+1)
    sns.kdeplot(df_manager[features[i]])

# %%
features = df_general.describe().columns
plt.figure(figsize=[10,10])
for i in range(0, len(features)):
    plt.subplot(4, 4, i+1)
    sns.boxplot(df_general[features[i]])

# %%
plt.figure(figsize=[10,15])
for i in range(0, len(features)):
    plt.subplot(4, 4, i+1)
    sns.kdeplot(df_general[features[i]])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9556\982272384.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_general[features[i]])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9556\982272384.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_general[features[i]])

# %%
df_general['DistanceFromHome_log'] = np.log1p(df_general['DistanceFromHome'])
df_general['MonthlyIncome_log'] = np.log1p(df_general['MonthlyIncome'])
df_general['NumCompaniesWorked_log'] = np.log1p(df_general['NumCompaniesWorked'])
df_general['PercentSalaryHike_log'] = np.log1p(df_general['PercentSalaryHike'])
df_general['TotalWorkingYears_log'] = np.log1p(df_general['TotalWorkingYears'])
df_general['YearsAtCompany_log'] = np.log1p(df_general['YearsAtCompany'])
df_general['YearsSinceLastPromotion_log'] = np.log1p(df_general['YearsSinceLastPromotion'])
df_general['YearsWithCurrManager_log'] = np.log1p(df_general['YearsWithCurrManager'])

# %%
plt.figure(figsize=[15,30])
features = df_general.describe().columns
for i in range(0, len(features)):
    plt.subplot(8, 4, i+1)
    sns.kdeplot(df_general[features[i]])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9556\1042200329.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_general[features[i]])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9556\1042200329.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df_general[features[i]])

# %% [markdown]
# ### Tipe Data

# %%
df_in_time.iloc[:, 1:] = df_in_time.iloc[:, 1:].apply(pd.to_datetime)
df_out_time.iloc[:, 1:] = df_out_time.iloc[:, 1:].apply(pd.to_datetime)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9556\3446605197.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT
#         ..
# 4405   NaT
# 4406   NaT
# 4407   NaT
# 4408   NaT
# 4409   NaT
# Name: 2015-01-01, Length: 4410, dtype: datetime64[ns]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_in_time.iloc[:, 1:] = df_in_time.iloc[:, 1:].apply(pd.to_datetime)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9556\3446605197.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT
#         ..
# 4405   NaT
# 4406   NaT
# 4407   NaT
# 4408   NaT
# 4409   NaT
# ...

# %% [markdown]
# ### Inconsistent Data & Anomaly Data

# %%
df_employee.describe()
# Out:
#         EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# count  4410.000000              4410.000000      4410.000000      4410.000000
# mean   2205.500000                 2.725170         2.734014         2.763492
# std    1273.201673                 1.089852         1.102071         0.703541
# min       1.000000                 1.000000         1.000000         1.000000
# 25%    1103.250000                 2.000000         2.000000         2.000000
# 50%    2205.500000                 3.000000         3.000000         3.000000
# 75%    3307.750000                 4.000000         4.000000         3.000000
# max    4410.000000                 4.000000         4.000000         4.000000

# %%
df_manager.describe()
# Out:
#         EmployeeID  JobInvolvement  PerformanceRating
# count  4410.000000     4410.000000        4410.000000
# mean   2205.500000        2.729932           3.153741
# std    1273.201673        0.711400           0.360742
# min       1.000000        1.000000           3.000000
# 25%    1103.250000        2.000000           3.000000
# 50%    2205.500000        3.000000           3.000000
# 75%    3307.750000        3.000000           3.000000
# max    4410.000000        4.000000           4.000000

# %%
df_general.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4410.000000        4410.000000
# mean      2.063946   65029.312925            2.687528          15.209524
# ...

# %%
categoricals = ['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18']
df_general[categoricals].describe()
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %% [markdown]
# ### Anomaly Data

# %%
df_general[categoricals].describe()
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %%
df_general.drop(columns='Over18',inplace=True)

# %%
df_general.drop(columns='EmployeeCount',inplace=True)
df_general.drop(columns='StandardHours',inplace=True)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Dataset Overview atau Deskripsi Data

# %%
work_hours = df_out_time.iloc[:, 1:] - df_in_time.iloc[:, 1:]

# %%
work_hours = (df_out_time.iloc[:, 1:] - df_in_time.iloc[:, 1:]) / pd.Timedelta(hours=1)

# %%
total_work_hours = work_hours.sum(axis=1)

# %%
average_work_hours = work_hours.mean(axis=1)

# %%
# convert datetime
df_in_time.iloc[:, 1:] = df_in_time.iloc[:, 1:].apply(pd.to_datetime, errors='coerce')
df_out_time.iloc[:, 1:] = df_out_time.iloc[:, 1:].apply(pd.to_datetime, errors='coerce')

# ubah ke long format
in_long = df_in_time.melt(id_vars=['Unnamed: 0'],
                     var_name='date',
                     value_name='in_time')

out_long = df_out_time.melt(id_vars=['Unnamed: 0'],
                       var_name='date',
                       value_name='out_time')

# merge
df = in_long.merge(out_long, on=['Unnamed: 0', 'date'])

# drop null
df = df.dropna(subset=['in_time', 'out_time'])

# hitung jam kerja per hari
df['work_hours'] = (df['out_time'] - df['in_time']).dt.total_seconds() / 3600

# buang data error
df = df[df['work_hours'] >= 0]

# tentukan overwork (>= 9 jam)
df['is_overwork'] = df['work_hours'] >= 9

# hitung jumlah hari overwork per karyawan
overwork_days = df.groupby('Unnamed: 0')['is_overwork'].sum()
overwork_days = overwork_days.reset_index(drop=True)

# %%
df_in_out = pd.concat(
    [total_work_hours, average_work_hours, overwork_days],
    axis=1
)

df_in_out.columns = ['total_work_hours', 'average_work_hours', 'overwork_days']
df_in_out = df_in_out.reset_index()

# %%
df_in_out['overwork'] = df_in_out['total_work_hours'].apply(
    lambda x: 'Yes' if x > 2080 else 'No'
)

# %%
# drop kolom index
df_in_out = df_in_out.drop(columns=['index'])

# tambah EmployeeID mulai dari 1
df_in_out.insert(0, 'EmployeeID', range(1, len(df_in_out) + 1))

# %%
df_in_out.head()
# Out:
#    EmployeeID  total_work_hours  average_work_hours  overwork_days overwork
# 0           1       1710.686944            7.373651              0       No
# 1           2       1821.676667            7.718969              0       No
# 2           3       1697.204167            7.013240              0       No
# 3           4       1690.514444            7.193678              0       No
# 4           5       1961.512778            8.006175              0       No

# %%
final_df = pd.merge(df_general, df_employee, on='EmployeeID')
final_df = pd.merge(final_df,df_manager, on='EmployeeID')
final_df = pd.merge(final_df,df_in_out, on='EmployeeID')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          4410 non-null   int64
#  1   Attrition                    4410 non-null   object
#  2   BusinessTravel               4410 non-null   object
#  3   Department                   4410 non-null   object
#  4   DistanceFromHome             4410 non-null   int64
#  5   Education                    4410 non-null   int64
#  6   EducationField               4410 non-null   object
#  7   EmployeeID                   4410 non-null   int64
#  8   Gender                       4410 non-null   object
#  9   JobLevel                     4410 non-null   int64
#  10  JobRole                      4410 non-null   object
#  11  MaritalStatus                4410 non-null   object
#  12  MonthlyIncome                4410 non-null   int64
# ...

# %%
numeric_df = final_df.select_dtypes(include='number')
final_df.describe()
# Out:
#                Age  DistanceFromHome    Education   EmployeeID     JobLevel  \
# count  4410.000000       4410.000000  4410.000000  4410.000000  4410.000000
# mean     36.923810          9.192517     2.912925  2205.500000     2.063946
# std       9.133301          8.105026     1.023933  1273.201673     1.106689
# min      18.000000          1.000000     1.000000     1.000000     1.000000
# 25%      30.000000          2.000000     2.000000  1103.250000     1.000000
# 50%      36.000000          7.000000     3.000000  2205.500000     2.000000
# 75%      43.000000         14.000000     4.000000  3307.750000     3.000000
# max      60.000000         29.000000     5.000000  4410.000000     5.000000
#
#        MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count    4410.000000         4410.000000        4410.000000       4410.000000
# mean    65029.312925            2.687528          15.209524          0.793878
# ...

# %%
categoricals_df = final_df.select_dtypes(exclude='number').columns
final_df[categoricals_df].describe()
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus overwork
# count              4410          4410     4410
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                978          2019     3496

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Label Encoding

# %%
final_df['Attrition'] = final_df['Attrition'].map({'Yes': 1, 'No': 0})
final_df['isMale'] = final_df['Gender'].map({'Male': 1, 'Female': 0})
final_df['overwork'] = final_df['overwork'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# #### One Hot Encoding

# %%
df_encoded = pd.get_dummies(final_df, columns=['BusinessTravel'])
df_encoded = pd.get_dummies(df_encoded, columns=['Department'])
df_encoded = pd.get_dummies(df_encoded, columns=['EducationField'])
df_encoded = pd.get_dummies(df_encoded, columns=['JobRole'])
df_encoded = pd.get_dummies(df_encoded, columns=['MaritalStatus'])
df_encoded
# Out:
#       Age  Attrition  DistanceFromHome  Education  EmployeeID  Gender  \
# 0      51          0                 6          2           1  Female
# 1      31          1                10          1           2  Female
# 2      32          0                17          4           3    Male
# 3      38          0                 2          5           4    Male
# 4      32          0                10          1           5    Male
# ...   ...        ...               ...        ...         ...     ...
# 4405   42          0                 5          4        4406  Female
# 4406   29          0                 2          4        4407    Male
# 4407   25          0                25          2        4408    Male
# 4408   42          0                18          2        4409    Male
# 4409   40          0                28          3        4410    Male
#
#       JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  ...  \
# ...

# %%
plt.figure(figsize=[15,15])
for i in range(0, len(categoricals_df)):
    plt.subplot(2,4, i+1)
    sns.countplot(x=final_df[categoricals_df[i]])

# %% [markdown]
# ### Univariate Analysis

# %%
plt.figure(figsize=[15,15])
for i in range(0, len(categoricals_df)):
    plt.subplot(2,4, i+1)
    sns.countplot(x=final_df[categoricals_df[i]])

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(15,15))
numericalcol = final_df.describe().columns
sns.heatmap(final_df[numericalcol].corr(),cmap='Blues',annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ### Statistik Deskriptif

# %% [markdown]
# ### Identifikasi fitur yang relevan
